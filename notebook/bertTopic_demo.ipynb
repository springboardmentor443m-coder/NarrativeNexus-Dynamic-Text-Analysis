# %%
# !pip install bertopic

# %%
from bertopic import BERTopic
import json
import pandas as pd

# %%
pip install bertopic scikit-learn sentence-transformers
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.datasets import fetch_20newsgroups

# Load the full dataset
newsgroups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

docs = newsgroups.data

len(docs)
# Out:
# 18846

# %%
topic_model = BERTopic(embedding_model="all-MiniLM-L6-v2")

# %%
docs_small = docs[:2000]   # try 2k docs first
docs_small_clean = [d for d in docs_small if len(d.split()) > 20]
topics, probs = topic_model.fit_transform(docs_small_clean)

# %%
topic_model.get_topic_info()
# Out:
#    Topic  Count             Name  \
# 0      0   1601  0_the_to_of_and
# 1      1    183  1_the_to_and_in
#
#                                    Representation  \
# 0  [the, to, of, and, is, in, that, it, for, you]
# 1    [the, to, and, in, of, that, he, is, it, on]
#
#                                  Representative_Docs
# 0  [In <lsjc8cINNmc1@saltillo.cs.utexas.edu> turp...
# 1  [\nNot particularly *in* the World Series. Dur...

# %%
topic_model.get_topic(topic=0)
# Out:
# [('the', np.float64(0.12595836209250383)),
#  ('to', np.float64(0.07996179373601733)),
#  ('of', np.float64(0.07604995574623671)),
#  ('and', np.float64(0.0673519339290852)),
#  ('is', np.float64(0.054081094647906724)),
#  ('in', np.float64(0.0531708708557883)),
#  ('that', np.float64(0.05195245734846331)),
#  ('it', np.float64(0.04536216236985599)),
#  ('for', np.float64(0.03876096458167584)),
#  ('you', np.float64(0.03825315098379721))]

# %%
topic_model.get_representative_docs(0)
# Out:
# ['In <lsjc8cINNmc1@saltillo.cs.utexas.edu> turpin@cs.utexas.edu (Russell Turpin)\n\n\nI regard love as no more or less "benign" than any other Christian does.\nYou are merely expressing "approval" of the consequences I find therein.\nWhich says more about our politics and cultural trappings than about my\n(or any) religion.  "Love" is a highly ambiguous word, of which Christians\ncan write both the "gentle" words Paul uses of it in 1 Corinthians -- in\na passage that even the "conservatives" will quote at you :-) -- and the\nwords of T. S. Eliot in his Pentacost Hymn, "Love is the unfamiliar Name\nthat wove the intolerable shirt of flame ..."\n\nThis is in any case rather to the side of what I was attempting to raise\nin my note, as will become more evident below.\n\n\nblechhh.  I think you are misreading me, rather seriously.  Though,\ngiven my principle that one CANNOT force one\'s own notion of "sin" on\nanother, and my unshakeable "disestablishmentarianism", Russel Turpin\nand ot
# ...

# %%
df = pd.DataFrame({'topic': topics, 'document': docs_small_clean})
df.loc[df["topic"] == 0]
# Out:
#       topic                                           document
# 1         0  My brother is in the market for a high-perform...
# 2         0  \n\n\n\n\tFinally you said what you dream abou...
# 3         0  \nThink!\n\nIt's the SCSI card doing the DMA t...
# 4         0  1)    I have an old Jasmine drive which I cann...
# 5         0  \n\nBack in high school I worked as a lab assi...
# ...     ...                                                ...
# 1779      0  We are making a transition from NextStep to X-...
# 1780      0  The problems with Catholic liturgy are likely ...
# 1781      0  \n\nNo matter how "absurd" it is to suggest th...
# 1782      0  Anyone here know if NCD is doing educational p...
# 1783      0  I know that the placebo effect is where a pati...
#
# [1601 rows x 2 columns]

# %%
#topic_model.visualize_topics()
topic_model.visualize_topics(use_ctfidf=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 #topic_model.visualize_topics()
# ----> 2 topic_model.visualize_topics(use_ctfidf=True)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\bertopic\_bertopic.py:2442, in BERTopic.visualize_topics(self, topics, top_n_topics, use_ctfidf, custom_labels, title, width, height)
#    2409 """Visualize topics, their sizes, and their corresponding words.
#    2410
#    2411 This visualization is highly inspired by LDAvis, a great visualization
#    (...)   2439 ```
#    2440 """
#    2441 check_is_fitted(self)
# -> 2442 return plotting.visualize_topics(
#    2443     self,
#    2444     topics=topics,
#    2445     top_n_topics=top_n_topics,
#    2446     use_ctfidf=use_ctfidf,
#    2447     custom_labels=custom_labels,
#    2448     title=title,
#    2449     width=width,
# ...

# %%
topic_model.visualize_barchart()

# %%
topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
