# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup
import re

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'AI Narrative Nexus-1.pdf',
#  'app.ipynb',
#  'cleaned_output.txt',
#  'data_loader.py',
#  'nlp_preprocessing_1.txt',
#  'regex',
#  'test_book.ipynb',
#  'ui_app.py',
#  '__pycache__']

# %%
def clean_html_file(file_path):

    # Read file
    with open(file_path, "r", encoding="utf-8") as f:
        html_content = f.read()

    # Use BeautifulSoup to parse HTML and remove tags
    soup = BeautifulSoup(html_content, "html.parser")

    for tag in soup(["html"]):
        tag.unwrap()   # removes the tag but keeps the content inside
    
    for tag in soup(["style"]):
        tag.extract()  # removes tag and content (we don't need script/style)


    # Get visible text only
    text = soup.get_text(separator=" ")

    # Clean extra spaces and symbols
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# %%
file_path = "nlp_preprocessing_1.txt"  # 🔹 Your .txt or .html file name
cleaned_text = clean_html_file(file_path)

print("Cleaned Text:\n")
print(cleaned_text[:9000])  # Print first 9000 chars
# Out:
# Cleaned Text:
#
# ...
